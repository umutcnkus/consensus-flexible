# %%
#!/usr/bin/python3

import matplotlib.pyplot as plt
import numpy as np
# line cyclers adapted to colourblind people
from cycler import cycler
line_cycler   = (cycler(color=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]) +
                 cycler(linestyle=["solid", "--", "-.", ":",(0, (3, 5, 1, 5, 1, 5)), "--", "-."]))
marker_cycler = (cycler(color=["#E69F00", "#56B4E9", "#009E73", "#0072B2", "#D55E00", "#CC79A7", "#F0E442"]) +
                 cycler(linestyle=["none", "none", "none", "none", "none", "none", "none"]) +
                 cycler(marker=["4", "2", "3", "1", "+", "x", "."]))

# matplotlib's standard cycler
standard_cycler = cycler("color", ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])

plt.rc("axes", prop_cycle=line_cycler)
plt.rc("font", family="serif", size=18.)
plt.rc("savefig", dpi=200)
plt.rc("legend", loc="best", fontsize="medium", fancybox=True, framealpha=0.5)
plt.rc("lines", linewidth=2.5, markersize=10, markeredgewidth=2.5)

import matlab.engine
eng = matlab.engine.connect_matlab()

# %%
time = eng.workspace['time'];

out0 = eng.workspace['out0'];
out1 = eng.workspace['out1'];
out2 = eng.workspace['out2'];
out3 = eng.workspace['out3'];
out4 = eng.workspace['out4'];

err1 = eng.workspace['err1'];
err2 = eng.workspace['err2'];
err3 = eng.workspace['err3'];
err4 = eng.workspace['err4'];

# %%
time = np.linspace(0 , 50, out1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   out0, label="Referans Üreteci");
plt.plot(time,   out1, label="Ajan 0");
plt.plot(time,   out2, label="Ajan 1");
plt.plot(time,   out3, label="Ajan 2");
plt.plot(time,   out4, label="Ajan 3");
plt.legend(loc='upper right');
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Çıkış Gerilimi");
plt.savefig('rlc-full-state-closed-all.pdf')

# %%
time = np.linspace(0 , 50, err1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   err1, label="Ajan 1");
plt.plot(time,   err2, label="Ajan 2");
plt.plot(time,   err3, label="Ajan 3");
plt.plot(time,   err4, label="Ajan 4");
plt.legend();
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Komşu Takip Hatası");
plt.savefig('rlc-full-state-neigh-tracking-error-all.pdf')

# %%
time = np.linspace(0 , 50, out1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   out0, label="Referans Üreteci");
plt.plot(time,   out1, label="Ajan 0");
plt.plot(time,   out2, label="Ajan 1");
plt.plot(time,   out3, label="Ajan 2");
plt.plot(time,   out4, label="Ajan 3");
plt.legend(loc='upper right');
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Çıkış Gerilimi");
plt.savefig('rlc-open-all.pdf')

# %%
time = np.linspace(0 , 250, out1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   out0, label="Referans Üreteci", linewidth=1.5);
plt.plot(time,   out1, label="Ajan 0", linewidth=1.5);
plt.plot(time,   out2, label="Ajan 1", linewidth=1.5);
plt.plot(time,   out3, label="Ajan 2", linewidth=1.5);
plt.plot(time,   out4, label="Ajan 3", linewidth=1.5, linestyle=(0, (3, 1, 1, 1, 1, 1)));
plt.legend(loc='upper right');
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Çıkış Gerilimi");
plt.savefig('rlc-observer-closed-all.pdf')

# %%
time = np.linspace(0 , 250, err1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   err1, label="Ajan 1", linewidth=1.5);
plt.plot(time,   err2, label="Ajan 2", linewidth=1.5);
plt.plot(time,   err3, label="Ajan 3", linewidth=1.5);
plt.plot(time,   err4, label="Ajan 4", linewidth=1.5);
plt.legend();
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Komşu Takip Hatası");
plt.savefig('rlc-observer-neigh-tracking-error-all.pdf')

# %%
time = np.linspace(0 , 250, err1.size[0]);
serr1 = eng.workspace['serr1'];
serr2 = eng.workspace['serr2'];
serr3 = eng.workspace['serr3'];
serr4 = eng.workspace['serr4'];
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time, serr1, label="Ajan 1");
plt.plot(time, serr2, label="Ajan 2");
plt.plot(time, serr3, label="Ajan 3");
plt.plot(time, serr4, label="Ajan 4");
plt.legend();
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Durum Kestirim Hatası");
plt.savefig('rlc-observer-state-tracking-error-all.pdf')

# %%
time = np.linspace(0 , 250, out1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   out0, label="Referans Üreteci", linewidth=1.5);
plt.plot(time,   out1, label="Ajan 0", linewidth=1.5);
plt.plot(time,   out2, label="Ajan 1", linewidth=1.5);
plt.plot(time,   out3, label="Ajan 2", linewidth=1.5);
plt.plot(time,   out4, label="Ajan 3", linewidth=1.5, linestyle=(0, (3, 1, 1, 1, 1, 1)));
plt.legend(loc='upper right');
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Çıkış Gerilimi");
plt.savefig('rlc-lokal-closed-all.pdf')

# %%
time = np.linspace(0 , 250, err1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time,   err1, label="Ajan 1", linewidth=1.5);
plt.plot(time,   err2, label="Ajan 2", linewidth=1.5);
plt.plot(time,   err3, label="Ajan 3", linewidth=1.5);
plt.plot(time,   err4, label="Ajan 4", linewidth=1.5);
plt.legend();
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Komşu Takip Hatası");
plt.savefig('rlc-lokal-neigh-tracking-error-all.pdf')

# %%
time = np.linspace(0 , 250, err1.size[0]);
serr1 = eng.workspace['serr1'];
serr2 = eng.workspace['serr2'];
serr3 = eng.workspace['serr3'];
serr4 = eng.workspace['serr4'];
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(12,6));
plt.figure();
plt.plot(time, serr1, label="Ajan 1");
plt.plot(time, serr2, label="Ajan 2");
plt.plot(time, serr3, label="Ajan 3");
plt.plot(time, serr4, label="Ajan 4");
plt.legend();
plt.grid();
plt.xlabel("Zaman[ms]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Durum Kestirim Hatası");
plt.savefig('rlc-lokal-state-tracking-error-all.pdf')

# %%
iout1 = eng.workspace['iout1'];
iout2 = eng.workspace['iout2'];
iout3 = eng.workspace['iout3'];
iout4 = eng.workspace['iout4'];
iout5 = eng.workspace['iout5'];

iiout1 = eng.workspace['iiout1'];
iiout2 = eng.workspace['iiout2'];
iiout3 = eng.workspace['iiout3'];
iiout4 = eng.workspace['iiout4'];
iiout5 = eng.workspace['iiout5'];
time = np.linspace(0 , 5, iout1.size[0]);
plt.rc("axes", prop_cycle=line_cycler);
plt.rc('figure', figsize=(18,12));
plt.figure();
plt.subplot(1, 2, 1)
plt.plot(time, iout1, label="Ajan 1");
plt.plot(time, iout2, label="Ajan 2");
plt.plot(time, iout3, label="Ajan 3");
plt.plot(time, iout4, label="Ajan 4");
plt.plot(time, iout5, label="Ajan 5");
plt.legend();
plt.grid();
plt.xlabel("Zaman[s]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Sistem Çıkışları");
plt.subplot(1, 2, 2)
plt.plot(time, iiout1, label="Ajan 1");
plt.plot(time, iiout2, label="Ajan 2");
plt.plot(time, iiout3, label="Ajan 3");
plt.plot(time, iiout4, label="Ajan 4");
plt.plot(time, iiout5, label="Ajan 5");
plt.legend();
plt.grid();
plt.xlabel("Zaman[s]");
plt.xlim(time[0], time[-1]);
plt.ylabel("Sistem Çıkışları");
# plt.savefig('integrator-response.pdf')
